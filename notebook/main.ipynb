# %% [markdown]
# # Equity Research Report Generator
# **Spring 2026 — LLM Term Project**
#
# Run cells top to bottom. Cell (5) generates the report; cell (7) exports it to PDF.

# %%
import pandas as pd

# %%
# (1) Install dependencies
# !pip -q install langgraph langchain-core langchain-community openai pydantic tenacity rich faiss-cpu sentence-transformers yfinance pypdf pandas python-dotenv markdown requests

# %%
# (2) Project paths — change PROJECT_ROOT if you move the folder
import os, sys

PROJECT_ROOT = r"C:\Users\manoj\OneDrive\Manu\Domain knowlege\7.Financial Engineering\1.Financial engineering\19.Spring 2026\2. Large Language model\project"
NOTEBOOK_DIR = os.path.join(PROJECT_ROOT, "notebook")
DATA_DIR     = os.path.join(PROJECT_ROOT, "data")

# Add notebook folder to Python path so imports resolve
if NOTEBOOK_DIR not in sys.path:
    sys.path.insert(0, NOTEBOOK_DIR)

# Create dirs if they don't exist yet
os.makedirs(NOTEBOOK_DIR, exist_ok=True)
os.makedirs(DATA_DIR,     exist_ok=True)

print(f"Notebook : {NOTEBOOK_DIR}")
print(f"Data     : {DATA_DIR}")
# Out:
# Notebook : C:\Users\manoj\OneDrive\Manu\Domain knowlege\7.Financial Engineering\1.Financial engineering\19.Spring 2026\2. Large Language model\project\notebook
# Data     : C:\Users\manoj\OneDrive\Manu\Domain knowlege\7.Financial Engineering\1.Financial engineering\19.Spring 2026\2. Large Language model\project\data

# %%
# (3) Load secrets from .env
# Copy .env.example → .env and fill in your keys. Never commit .env to git.
#from dotenv import load_dotenv
#import os

#load_dotenv(dotenv_path=os.path.join(PROJECT_ROOT, ".env"), override=True)

# Confirm keys loaded (values masked)

#for key in ["OPENROUTER_API_KEY", "WP_SITE_URL", "WP_USERNAME", "WP_APP_PASSWORD"]:
#    val = os.getenv(key, "")
#    print(f"{key}: {'✓ set' if val else '✗ MISSING'}")

# %%
import os
print(repr(os.getenv("OPENROUTER_API_KEY")))
# Out:
# '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'

# %%
import os
os.environ["OPENROUTER_API_KEY"] = "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"

# %%
# (4) Import the graph
from orchestrator import run_report
from rich import print as rprint
rprint('[bold green]Graph ready ✓[/bold green]')
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Graph ready ✓

# %%
# (5) Run — Goldman Sachs
#
# Expected data layout:
#   data\gs_filings\FRY9C_2380443_20250930.csv
#   data\gs_filings\FFIEC102_2380443_20250930.csv
#   data\gs_filings\2024-annual-report.pdf

TICKER       = 'GS'
FILING_DATE  = '20250930'
CSV_FOLDER   = os.path.join(DATA_DIR, 'gs_filings')
PDF_PATHS    = [os.path.join(DATA_DIR, 'gs_filings', '2024-annual-report.pdf')]

report = run_report(
    ticker      = TICKER,
    pdf_paths   = PDF_PATHS,
    csv_folder  = CSV_FOLDER,
    filing_date = FILING_DATE,
)

print(report[:3000])   # preview first 3000 chars
# Out:
# Ingested 488 chunks ← C:\Users\manoj\OneDrive\Manu\Domain knowlege\7.Financial Engineering\1.Financial
# engineering\19.Spring 2026\2. Large Language model\project\data\gs_filings\2024-annual-report.pdf
# Ingested market risk data ← GS 20250930
# RAG store: 489 chunks indexed
# Sections to write: 7 | max 4 tool calls/section | 180s timeout/section
# ▶ [1/7] Section: investment_thesis
#   LLM call #1 | tools used: 0 | elapsed: 0s
#   → {"type":"tool","name":"run_dcf_valuation","arguments":{"ticker":"GS"}}…
#   tool [1/4]: run_dcf_valuation({'ticker': 'GS'})
#   result preview: {'ticker': 'GS', 'current_price': 841.84, 'price_target': 190.27, 'upside_pct': -77.4,
# 'equity_value_$B': 56.46, 'pv_fcf
#   LLM call #2 | tools used: 1 | elapsed: 0s
#   → {"type":"tool","name":"fetch_financials","arguments":{"ticker":"GS"}}…
#   tool [2/4]: fetch_financials({'ticker': 'GS'})
#   result preview: {'ticker': 'GS', 'company_name': 'The Goldman Sachs Group, Inc.', 'sector': 'Financial Services',
# 'industry': 'Capital M
#   LLM call #3 | tools used: 2 | elapsed: 0s
#   → {"type":"final","section":"investment_thesis","content":"**Sell | PT $190.27 | -77.4% downside | 12-…
#   ✓ saved: investment_thesis  (1583 chars, 0s, 2 tool calls)
# ▶ [2/7] Section: executive_summary
#   LLM call #4 | tools used: 0 | elapsed: 0s
#   → {"type":"final","section":"executive_summary","content":"We rate Goldman Sachs as a Sell with a pric…
#   ✓ saved: executive_summary  (476 chars, 0s, 0 tool calls)
# ▶ [3/7] Section: business_overview
#   LLM call #5 | tools used: 0 | elapsed: 0s
#   → {"type":"retrieve_context","arguments":{"query":"Goldman Sachs revenue segments","k":5}}…
#   LLM call #6 | tools used: 0 | elapsed: 0s
#   → {"type":"tool","name":"retrieve_context","arguments":{"query":"Goldman Sachs revenue segments","k":5…
#   tool [1/4]: retrieve_context({'query': 'Goldman Sachs revenue segments', 'k': 5})
#   result preview: unchanged compared with 2023.M arket making revenues from intermediation activities were slightly
# higher, primarily refl
#   LLM call #7 | tools used: 1 | elapsed: 0s
#   → {"type":"final","section":"business_overview","content":"Goldman Sachs operates through three primar…
#   ✓ saved: business_overview  (938 chars, 0s, 1 tool calls)
# ▶ [4/7] Section: financial_performance
#   LLM call #8 | tools used: 0 | elapsed: 0s
#   → {"type":"final","section":"financial_performance","content":"Goldman Sachs reported annual revenue o…
#   ✓ saved: financial_performance  (850 chars, 0s, 0 tool calls)
# ▶ [5/7] Section: valuation
#   LLM call #9 | tools used: 0 | elapsed: 0s
#   → {"type":"run_dcf_valuation","arguments":{"ticker":"GS"}}…
#   LLM call #10 | tools used: 0 | elapsed: 0s
#   → {"type":"fetch_financials","arguments":{"ticker":"GS"}}…
#   LLM call #11 | tools used: 0 | elapsed: 0s
#   → {"type":"fetch_financials","arguments":{"ticker":"JPM"}}…
#   LLM call #12 | tools used: 0 | elapsed: 0s
#   → {"type":"fetch_financials","arguments":{"ticker":"MS"}}…
#   LLM call #13 | tools used: 0 | elapsed: 0s
#   → {"type":"final","section":"valuation","content":"Our DCF analysis for Goldman Sachs yields an intrin…
#   ✓ saved: valuation  (732 chars, 0s, 0 tool calls)
# ▶ [6/7] Section: industry_analysis
#   LLM call #14 | tools used: 0 | elapsed: 0s
#   → {"type":"retrieve_context","arguments":{"query":"current cycle position of the financial services in…
#   LLM call #15 | tools used: 0 | elapsed: 0s
#   → {"type":"retrieve_context","arguments":{"query":"top competitors of Goldman Sachs","k":5}}…
#   LLM call #16 | tools used: 0 | elapsed: 0s
#   → {"type":"final","section":"industry_analysis","content":"The financial services industry is currentl…
#   ✓ saved: industry_analysis  (812 chars, 0s, 0 tool calls)
# ▶ [7/7] Section: risks
#   LLM call #17 | tools used: 0 | elapsed: 0s
#   → {"type":"fetch_market_risk_data","arguments":{"ticker":"GS","date":"20230930","csv_folder":"./data"}…
#   LLM call #18 | tools used: 0 | elapsed: 0s
#   → {"type":"final","section":"risks","content":"| Risk | Severity | Trigger | PT Impact |\n|------|----…
#   ✓ saved: risks  (690 chars, 0s, 0 tool calls)
# ✓ Report compiled: 7/7 sections, 6,302 chars
# Total time: 84s (1.4 min)
# # Equity Research Report — GS
# _Generated 2026-03-26 06:06:06_
#
#
# ## Investment Thesis
#
# **Sell | PT $190.27 | -77.4% downside | 12-month horizon**
#
# ## Bull Case
# - **Strong Revenue Growth**: We expect Goldman Sachs to leverage its robust Global Banking & Markets segment to drive revenue growth, potentially reaching $65 billion, a 9% increase from the current $59.4 billion.
# - **Asset & Wealth Management Expansion**: We forecast an increase in assets under management by 10% over the next year, enhancing fee income and contributing to a higher ROE, potentially reaching 15%.
# - **Strategic Acquisitions**: We believe strategic acquisitions in fintech could enhance Goldman Sachs' technological capabilities, potentially increasing its market cap by 5%.
#
# ## Bear Case
# - **Regulatory Risks**: We see potential regulatory changes impacting capital requirements, which could increase the CET1 ratio to 17%, constraining capital deployment.
# - **Market Volatility**: A significant downturn in capital markets could reduce trading revenues by 15%, impacting overall profitability.
# - **Interest Rate Fluctuations**: We expect fluctuations in interest rates to compress net interest margins, potentially reducing net income by 10%.
#
# ## Catalysts
# - **Quarterly Earnings Reports**: Upcoming earnings releases in Q1 and Q2 2024 will provide insights into revenue growth and cost management.
# - **Regulatory Announcements**: Any updates on capital requirements or stress test results expected in mid-2024 could impact investor sentiment.
# - **Strategic Initiatives**: Announcements regarding new fintech partnerships or acquisitions expected by late 2024 could drive stock performance.
#
#
# ## Executive Summary
#
# We rate Goldman Sachs as a Sell with a price target of $190.27, indicating a -77.4% downside. The most critical financial metric supporting our thesis is the current price-to-book ratio of 2.36, which suggests overvaluation relative to intrinsic value. The key near-term catalyst is the upcoming quarterly earnings report, expected in Q1 2024, which will provide insights into revenue growth and cost management, crucial for assessing the sustainability of current valuations.
#
#
# ## Business Overview
#
# Goldman Sachs operates through three primary revenue segments: Global Banking & Markets, Asset & Wealth Management, and Platform Solutions. Global Banking & Markets is the largest contributor, generating approximately $34.9 billion in revenue, driven by investment banking fees and FICC activities. Asset & Wealth Management contributes around $12 billion, focusing on investment management and advisory services. Platform Solutions, although smaller, is rapidly growing, contributing about $6 billion, driven by fintech initiatives and consumer banking.
#
# The Asset & Wealth Management segment is driving incremental growth, with a forecasted 10% increase in assets under management. A structural competitive advantage for Goldman Sachs is its extensive global network and deep client relationships, which

# %%
# (6) Save markdown to data\
md_file = os.path.join(DATA_DIR, f"{TICKER}_equity_report.md")

with open(md_file, 'w', encoding='utf-8') as f:
    f.write(report)

rprint(f"[bold]Markdown saved → {md_file}[/bold]")
# Out:
# Markdown saved → C:\Users\manoj\OneDrive\Manu\Domain knowlege\7.Financial Engineering\1.Financial
# engineering\19.Spring 2026\2. Large Language model\project\data\GS_equity_report.md

# %%
# (7) Export to PDF via pandoc + xelatex (MiKTeX)
import subprocess

pdf_file = os.path.join(DATA_DIR, f"{TICKER}_equity_report.pdf")

result = subprocess.run([
    "pandoc", md_file,
    "-o",  pdf_file,
    "--pdf-engine=xelatex",
    "-V",  "geometry:margin=1in",
    "-V",  "fontsize=11pt",
    "-V",  "mainfont=Times New Roman",
    "-V",  "colorlinks=true",
    "-V",  "urlcolor=blue",
    "--highlight-style=tango",
], capture_output=True, text=True)

if result.returncode == 0:
    rprint(f"[bold green]PDF saved → {pdf_file}[/bold green]")
else:
    rprint(f"[red]pandoc error:[/red]\n{result.stderr}")
# Out:
# PDF saved → C:\Users\manoj\OneDrive\Manu\Domain knowlege\7.Financial Engineering\1.Financial engineering\19.Spring
# 2026\2. Large Language model\project\data\GS_equity_report.pdf

# %%
# (8) Publish to WordPress.com
#
# Publishes the report as a DRAFT by default — review in WP Admin before going live.
# Change status="publish" to go live immediately.
#
# Pre-requisite: fill in WP_SITE_URL, WP_USERNAME, WP_APP_PASSWORD in your .env
# Get app password: WP Admin → Users → Profile → Application Passwords → Add New

#from publisher import publish_report

#POST_TITLE = f"{TICKER} Equity Research — {'Buy' if 'buy' in report.lower() else 'Hold'} | Bulge Bracket"

#result = publish_report(
#    report_md = report,
#    title     = POST_TITLE,
#    status    = "draft",       # change to "publish" when ready
#    tags      = [TICKER, "Equity Research", "Financial Analysis"],
#    excerpt   = report.split("\n\n")[1][:200] if "\n\n" in report else "",
#)

#rprint(f"[bold green]✓ Draft created[/bold green]")
#rprint(f"  Post ID  : {result['post_id']}")
#rprint(f"  View URL : {result['url']}")
#rprint(f"  Edit URL : {result['edit_url']}")
